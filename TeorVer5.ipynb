# %% [markdown]
# #Задача 1#
#
# Когда используется критерий Стьюдента, а когда Z –критерий?
#
# **Критерий Стьюдента используется если неизвестна сигма генеральной совокупности. Если сигма известна используется Z –критерий.**

# %%
n=10
masses = [2.51, 2.35, 2.74, 2.56, 2.40, 2.36, 2.65, 2.7, 2.67, 2.34]
m_3 = 2.5
average = sum(masses)/len(masses)
print(average)
sigma_n = 0
for i in masses:
  sigma_n += (i-average)*(i-average)
sigma_n = pow(sigma_n/(n-1),0.5)
print(sigma_n)
t_n = (average-m_3)/(sigma_n/pow(n,0.5))
print(t_n)
# Out:
# 2.5279999999999996
# 0.1572542173961923
# 0.5630613661802959

# %% [markdown]
# #Задача 2#
#
# Проведите тест гипотезы. Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм.
# Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 кв. мм.

# %% [markdown]
# *Сигма генеральной совокупности известна, используем Z-критерий.*
#
# SE = 𝞼/√n
# z = (x – μ) / (σ / √n)

# %%
sigma = 2
n = 100
x = 17.5
m = 17
Z = (x-m)/(sigma/pow(n,0.5))
print(Z)
# Out:
# 2.5

# %% [markdown]
# Z табличное = 1,645
#
# Z наблюдаемое = 2,5
#
# **Поскольку Z наблюдаемое > Z табличное, то верна первая гипотеза. Шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр отличный от 17 мм.**

# %% [markdown]
# #Задача 3#
#
# Проведите тест гипотезы. Продавец утверждает, что средний вес пачки печенья составляет 200 г.
#
# Из партии извлечена выборка из 10 пачек.
#
# Вес каждой пачки составляет: 202, 203, 199, 197, 195, 201, 200, 204, 194, 190.
#
# Известно, что их веса распределены нормально.
#
# Верно ли утверждение продавца, если учитывать,
#
# что доверительная вероятность равна 99%? (Провести двусторонний тест.)
#
# *Сигма генеральной совокупности неизвестна, следует  использовать критерий Стьюдента.*
#
# *t табличное для 9 степеней свободы и вероятности 0,995 - 3,25*
#
# t_н=(X ̅ - μ)/(σ_н/√n)

# %%
n=10
masses = [202, 203, 199, 197, 195, 201, 200, 204, 194, 190]
m_3 = 200
average = sum(masses)/len(masses)
sigma_n = 0
for i in masses:
  sigma_n += (i-average)*(i-average)
sigma_n = pow(sigma_n/(n-1),0.5)
t_n = (average-m_3)/(sigma_n/pow(n,0.5))
print(t_n)
# Out:
# -1.0651074037450896

# %% [markdown]
# t  табличное для 9 степеней свободы и вероятности 0,995 (двустороннее) = ±3,25
#
# t наблюдаемое = -1,0651
#
# **Поскольку t наблюдаемое лежит в диапазоне (-3,23;3,25), с вероятностью 0,995 верна нулевая гипотеза. Средний вес пачки печенья составляет 200 г.**

# %% [markdown]
# #Задача 4#
#
# Есть ли статистически значимые различия в росте дочерей?
#
# Рост матерей 172, 177, 158, 170, 178,175, 164, 160, 169, 165
#
# Рост взрослых дочерей: 173, 175, 162, 174, 175, 168, 155, 170, 160
#
#
# В соответствии с пояснениями преподавателя, что выборки должны рассматриваться как связанные (даны значения роста матерей и именно их дочерей, не соседских) из расчётов исключён последний элемент из выборки роста матерей для использования функции ttest_rel.
#
# Для определения наличия статистически значимых различий в росте дочерей необходимо провести t-тест Стьюдента, для чего можно воспользоваться функцией ttest_rel из пакета scipy.stats.
#
# Примем α=0,05.

# %%
from scipy.stats import ttest_rel

mothers = [172, 177, 158, 170, 178, 175, 164, 160, 169]
daughters = [173, 175, 162, 174, 175, 168, 155, 170, 160]

t_stat, p_value = ttest_rel(mothers, daughters)

print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: 0.559522990335608
# p-value: 0.5911212354055175

# %% [markdown]
# **Уровень p-value значительно больше α, следовательно статистически значимых различий в росте дочерей нет.**
